# %% [markdown]
# # Image classification: cats & dogs

# %%
# Handle imports up-front
import glob
import random
import itertools
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from keras.preprocessing import image
# Out:
# 2024-12-05 00:58:21.917828: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-05 00:58:22.147906: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-05 00:58:22.347687: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1733360302.645281    6411 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1733360302.712899    6411 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-05 00:58:23.354320: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## 1. Data preparation
#
# ### 1.1. Load the data paths

# %%
# Set the path to the training data
training_data_path='../data/data/train'

# Get a list of training dog and cat images
training_dogs=glob.glob(f'{training_data_path}/dog/dog.*')
training_cats=glob.glob(f'{training_data_path}/cat/cat.*')

# %% [markdown]
# ### 1.2. Inspect

# %%
fig, axs = plt.subplots(3,2,figsize=(6, 4))

for cat, dog, row in zip(training_cats, training_dogs, axs):
    for animal, ax in zip([cat, dog], row):
        animal=image.load_img(animal)
        animal=image.img_to_array(animal)
        animal/=255.0
        ax.imshow(animal)
        ax.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2. EDA
#
# Let's take a look at a few of our images to get a feel for how image data is structured.
#
# ### 2.1. Image data

# %%
# Load one of the images as an array and look at it's shape - what do you see, what are the dimensions? Are they what you expect?

# Load one of the dogs
dog=image.load_img(training_dogs[0])

# And convert it to an array - this is how TensorFlow will handel the data
dog=image.img_to_array(dog)

# Take a look at some properties of the object
print(f'Image data is: {type(dog)}')
print(f'Image data shape: {dog.shape}')
# Out:
# Image data is: <class 'numpy.ndarray'>
# Image data shape: (500, 390, 3)

# %%
# Plot a histogram of the three 2D arrays which comprise the image. What do you see?

plt.hist(dog[:,:,0].flatten(), bins=100, color='red', alpha=0.5, label='Red channel')
plt.hist(dog[:,:,1].flatten(), bins=100, color='green', alpha=0.5, label='Green channel')
plt.hist(dog[:,:,2].flatten(), bins=100, color='blue', alpha=0.5, label='Blue channel')
plt.xlabel('Pixel value')
plt.ylabel('Count')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ### 2.2. Image dimensions
#
# Let's take a look at a random sample of images from the dataset and see what their dimensions are.

# %%
# Loop over a few hundred images and extract their width and heigh, plot both as a histogram. What do you see, does this information matter to us, if so, how?

sample_size=1000
sample=random.sample(training_dogs, sample_size//2)
sample+=random.sample(training_cats, sample_size//2)

heights=[]
widths=[]

for sample_image in sample:

    sample_image=image.load_img(sample_image)
    sample_image=image.img_to_array(sample_image)
    heights.append(sample_image.shape[0])
    widths.append(sample_image.shape[1])

plt.hist(heights, bins=50, alpha=0.5, label='Image heights')
plt.hist(widths, bins=50, alpha=0.5, label='Image widths')
plt.xlabel('Image dimension')
plt.ylabel('Count')
plt.legend(loc='best')
plt.show()

# %%
sample_size=1000
sample=random.sample(training_dogs, sample_size//2)
sample+=random.sample(training_cats, sample_size//2)

heights=[]
widths=[]

image_dim = 128

for sample_image in sample:

    sample_image=image.load_img(sample_image)
    sample_image=image.img_to_array(sample_image)
    heights.append(sample_image.shape[0])
    widths.append(sample_image.shape[1])

plt.hist(heights, bins=50, alpha=0.5, label='Image heights')
plt.hist(widths, bins=50, alpha=0.5, label='Image widths')
plt.xlabel('Image dimension')
plt.ylabel('Count')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ### 2.3. Image aspect ratios

# %%
# Plot a histogram of the image aspect ratios (i.e. width/height) What do you see, does this information matter to us, if so, how?

# Calculate the sample image aspect ratios
aspect_ratios=np.array(widths)/np.array(heights)

# Plot as histogram
plt.hist(aspect_ratios, bins=50, color='black')
plt.xlabel('Image aspect ratio')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## 3. Build the model
#
# ### 3.1. Prepare images for streaming

# %%
def make_datasets(training_data_path: str, image_dim: int, batch_size: int=16):

    training_dataset=tf.keras.utils.image_dataset_from_directory(
        training_data_path,
        validation_split=0.2,
        subset='training',
        seed=315,
        image_size=(image_dim, image_dim),
        batch_size=batch_size
    ).repeat()

    validation_dataset=tf.keras.utils.image_dataset_from_directory(
        training_data_path,
        validation_split=0.2,
        subset='validation',
        seed=315,
        image_size=(image_dim, image_dim),
        batch_size=batch_size
    ).repeat()



    return training_dataset, validation_dataset,


training_dataset, validation_dataset=make_datasets(training_data_path, 128)
# Out:
# Found 25000 files belonging to 2 classes.
# Using 20000 files for training.
# Found 25000 files belonging to 2 classes.
# Using 5000 files for validation.

# %% [markdown]
# ### 3.1. Model definition

# %%
def compile_model(image_dim, learning_rate):

    initializer=tf.keras.initializers.GlorotUniform(seed=315)

    model=Sequential([
        layers.Input((image_dim, image_dim, 3)),
        layers.Rescaling(1./255),
        layers.Conv2D(16, 3, padding='same', activation='relu', kernel_initializer=initializer),
        layers.MaxPooling2D(),
        layers.Conv2D(32, 3, padding='same', activation='relu', kernel_initializer=initializer),
        layers.MaxPooling2D(),
        layers.Conv2D(64, 3, padding='same', activation='relu', kernel_initializer=initializer),
        layers.MaxPooling2D(),
        layers.Flatten(),
        layers.Dense(128, activation='relu', kernel_initializer=initializer),
        layers.Dense(1, activation='sigmoid', kernel_initializer=initializer)
    ])

    optimizer=keras.optimizers.Adam(learning_rate=learning_rate)
    model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['binary_accuracy'])

    return model

model=compile_model(128, 0.001)
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)           │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 128, 128, 16)   │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 64, 64, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 64, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 32, 32, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 16384)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     2,097,280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,120,993 (8.09 MB)
#  Trainable params: 2,120,993 (8.09 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### 3.2. Model training

# %%
training_results=model.fit(
  training_dataset,
  validation_data=validation_dataset,
  epochs=10,
  steps_per_epoch=5,
  validation_steps=5
)
# Out:
# Epoch 1/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 321ms/step - binary_accuracy: 0.4035 - loss: 0.8347 - val_binary_accuracy: 0.4500 - val_loss: 0.7030
# Epoch 2/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 226ms/step - binary_accuracy: 0.4630 - loss: 0.7006 - val_binary_accuracy: 0.6375 - val_loss: 0.6919
# Epoch 3/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 230ms/step - binary_accuracy: 0.5818 - loss: 0.6902 - val_binary_accuracy: 0.5125 - val_loss: 0.6924
# Epoch 4/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - binary_accuracy: 0.4866 - loss: 0.7035 - val_binary_accuracy: 0.4750 - val_loss: 0.7002
# Epoch 5/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 211ms/step - binary_accuracy: 0.3938 - loss: 0.7080 - val_binary_accuracy: 0.4500 - val_loss: 0.6939
# Epoch 6/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 236ms/step - binary_accuracy: 0.4877 - loss: 0.6919 - val_binary_accuracy: 0.5375 - val_loss: 0.6941
# Epoch 7/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 213ms/step - binary_accuracy: 0.5509 - loss: 0.6901 - val_binary_accuracy: 0.4875 - val_loss: 0.6922
# Epoch 8/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 226ms/step - binary_accuracy: 0.5715 - loss: 0.6931 - val_binary_accuracy: 0.4375 - val_loss: 0.6919
# Epoch 9/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - binary_accuracy: 0.6590 - loss: 0.6875 - val_binary_accuracy: 0.4625 - val_loss: 0.6997
# Epoch 10/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - binary_accuracy: 0.5179 - loss: 0.7033 - val_binary_accuracy: 0.4625 - val_loss: 0.6899

# %%
print(training_results.history.keys())
# Out:
# dict_keys(['binary_accuracy', 'loss', 'val_binary_accuracy', 'val_loss'])

# %%
# Take a look at what information 'training_results' contains. Plot the training and validation accuracy (and binary cross-entropy if you like) over the training epoch. Is the model learning? If not, what do you think is wrong?


import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(training_results.history['binary_accuracy'], label='Train Accuracy')
plt.plot(training_results.history['val_binary_accuracy'], label='Val Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(training_results.history['loss'], label='Train Loss')
plt.plot(training_results.history['val_loss'], label='Val Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3.3. Model optimization

# %%
learning_rates = [0.1, 0.01, 0.001]
batch_size = [16, 32, 64]
results = []

training_data_path = '../data/data/train'

for lr in learning_rates:
    for bs in batch_size:
        
        training_dataset, validation_dataset = make_datasets(training_data_path, image_dim=128, batch_size=bs)

       
        model = compile_model(image_dim=128, learning_rate=lr)

       
        result = model.fit(training_dataset, validation_data=validation_dataset, epochs=10, steps_per_epoch=5, validation_steps=5)

       
        results.append((lr, bs, result))
# Out:
# Found 25000 files belonging to 2 classes.
# Using 20000 files for training.
# Found 25000 files belonging to 2 classes.
# Using 5000 files for validation.
# Epoch 1/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 255ms/step - binary_accuracy: 0.4264 - loss: 8228.7246 - val_binary_accuracy: 0.4500 - val_loss: 0.7257
# Epoch 2/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 210ms/step - binary_accuracy: 0.5332 - loss: 7.2905 - val_binary_accuracy: 0.5125 - val_loss: 0.7728
# Epoch 3/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 241ms/step - binary_accuracy: 0.3719 - loss: 0.8213 - val_binary_accuracy: 0.4875 - val_loss: 0.6947
# Epoch 4/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - binary_accuracy: 0.4349 - loss: 0.7063 - val_binary_accuracy: 0.4750 - val_loss: 0.7294
# Epoch 5/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - binary_accuracy: 0.3938 - loss: 0.7634 - val_binary_accuracy: 0.4500 - val_loss: 0.7008
# Epoch 6/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 204ms/step - binary_accuracy: 0.5127 - loss: 0.6908 - val_binary_accuracy: 0.4625 - val_loss: 0.7058
# Epoch 7/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - binary_accuracy: 0.4491 - loss: 0.7120 - val_binary_accuracy: 0.5125 - val_loss: 0.6978
# Epoch 8/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 202ms/step - binary_accuracy: 0.4285 - loss: 0.7161 - val_binary_accuracy: 0.4375 - val_loss: 0.6959
# Epoch 9/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 197ms/step - binary_accuracy: 0.6590 - loss: 0.6962 - val_binary_accuracy: 0.4625 - val_loss: 0.7318
# Epoch 10/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 234ms/step - binary_accuracy: 0.5179 - loss: 0.7067 - val_binary_accuracy: 0.4625 - val_loss: 0.7099
# Found 25000 files belonging to 2 classes.
# Using 20000 files for training.
# Found 25000 files belonging to 2 classes.
# Using 5000 files for validation.
# Epoch 1/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 504ms/step - binary_accuracy: 0.5102 - loss: 4701.4180 - val_binary_accuracy: 0.5188 - val_loss: 0.9377
# Epoch 2/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 400ms/step - binary_accuracy: 0.5566 - loss: 2.4308 - val_binary_accuracy: 0.5813 - val_loss: 0.6862
# Epoch 3/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 419ms/step - binary_accuracy: 0.5169 - loss: 1.1496 - val_binary_accuracy: 0.5312 - val_loss: 0.7123
# Epoch 4/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 395ms/step - binary_accuracy: 0.5056 - loss: 2.2985 - val_binary_accuracy: 0.5312 - val_loss: 0.6922
# Epoch 5/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 391ms/step - binary_accuracy: 0.4870 - loss: 0.6968 - val_binary_accuracy: 0.4625 - val_loss: 0.6953
# Epoch 6/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 426ms/step - binary_accuracy: 0.4603 - loss: 0.6955 - val_binary_accuracy: 0.5250 - val_loss: 0.6928
# Epoch 7/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 393ms/step - binary_accuracy: 0.4825 - loss: 0.6995 - val_binary_accuracy: 0.5375 - val_loss: 0.6910
# Epoch 8/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 406ms/step - binary_accuracy: 0.4868 - loss: 0.7007 - val_binary_accuracy: 0.5625 - val_loss: 0.6854
# Epoch 9/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 420ms/step - binary_accuracy: 0.5503 - loss: 0.6884 - val_binary_accuracy: 0.5375 - val_loss: 0.6915
# Epoch 10/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 392ms/step - binary_accuracy: 0.5166 - loss: 0.6924 - val_binary_accuracy: 0.4875 - val_loss: 0.6938
# Found 25000 files belonging to 2 classes.
# Using 20000 files for training.
# Found 25000 files belonging to 2 classes.
# Using 5000 files for validation.
# Epoch 1/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - binary_accuracy: 0.5132 - loss: 7649.1831 - val_binary_accuracy: 0.5156 - val_loss: 209.6666
# Epoch 2/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 876ms/step - binary_accuracy: 0.4600 - loss: 128.2867 - val_binary_accuracy: 0.4812 - val_loss: 0.7262
# Epoch 3/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 889ms/step - binary_accuracy: 0.5000 - loss: 0.7310 - val_binary_accuracy: 0.5219 - val_loss: 0.7127
# Epoch 4/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 875ms/step - binary_accuracy: 0.5075 - loss: 0.7080 - val_binary_accuracy: 0.5031 - val_loss: 0.6974
# Epoch 5/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 875ms/step - binary_accuracy: 0.4782 - loss: 0.7055 - val_binary_accuracy: 0.5031 - val_loss: 0.7009
# Epoch 6/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 878ms/step - binary_accuracy: 0.5405 - loss: 0.6908 - val_binary_accuracy: 0.5219 - val_loss: 0.6937
# Epoch 7/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 884ms/step - binary_accuracy: 0.4714 - loss: 0.7025 - val_binary_accuracy: 0.4906 - val_loss: 0.6948
# Epoch 8/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 836ms/step - binary_accuracy: 0.4990 - loss: 0.6938 - val_binary_accuracy: 0.4656 - val_loss: 0.6942
# Epoch 9/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 882ms/step - binary_accuracy: 0.5558 - loss: 0.6918 - val_binary_accuracy: 0.5156 - val_loss: 0.6930
# Epoch 10/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 874ms/step - binary_accuracy: 0.4979 - loss: 0.6932 - val_binary_accuracy: 0.5000 - val_loss: 0.6932
# Found 25000 files belonging to 2 classes.
# Using 20000 files for training.
# Found 25000 files belonging to 2 classes.
# Using 5000 files for validation.
# Epoch 1/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 279ms/step - binary_accuracy: 0.4196 - loss: 5.2101 - val_binary_accuracy: 0.4500 - val_loss: 0.6970
# Epoch 2/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 233ms/step - binary_accuracy: 0.4389 - loss: 0.6978 - val_binary_accuracy: 0.5125 - val_loss: 0.6929
# Epoch 3/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 197ms/step - binary_accuracy: 0.3719 - loss: 0.6967 - val_binary_accuracy: 0.4875 - val_loss: 0.6932
# Epoch 4/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 199ms/step - binary_accuracy: 0.4967 - loss: 0.6934 - val_binary_accuracy: 0.4750 - val_loss: 0.6935
# Epoch 5/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 200ms/step - binary_accuracy: 0.3938 - loss: 0.6948 - val_binary_accuracy: 0.4500 - val_loss: 0.6936
# Epoch 6/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step - binary_accuracy: 0.4877 - loss: 0.6933 - val_binary_accuracy: 0.5375 - val_loss: 0.6930
# Epoch 7/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 225ms/step - binary_accuracy: 0.5509 - loss: 0.6930 - val_binary_accuracy: 0.4875 - val_loss: 0.6932
# Epoch 8/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - binary_accuracy: 0.5715 - loss: 0.6931 - val_binary_accuracy: 0.4375 - val_loss: 0.6934
# Epoch 9/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 199ms/step - binary_accuracy: 0.6590 - loss: 0.6926 - val_binary_accuracy: 0.4625 - val_loss: 0.6940
# Epoch 10/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 204ms/step - binary_accuracy: 0.5179 - loss: 0.6928 - val_binary_accuracy: 0.4625 - val_loss: 0.6943
# Found 25000 files belonging to 2 classes.
# Using 20000 files for training.
# Found 25000 files belonging to 2 classes.
# Using 5000 files for validation.
# Epoch 1/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 479ms/step - binary_accuracy: 0.4769 - loss: 3.8264 - val_binary_accuracy: 0.5437 - val_loss: 0.6914
# Epoch 2/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 427ms/step - binary_accuracy: 0.4511 - loss: 0.6972 - val_binary_accuracy: 0.5813 - val_loss: 0.6917
# Epoch 3/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 396ms/step - binary_accuracy: 0.5169 - loss: 0.6987 - val_binary_accuracy: 0.5312 - val_loss: 0.6924
# Epoch 4/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 404ms/step - binary_accuracy: 0.5123 - loss: 0.6928 - val_binary_accuracy: 0.4688 - val_loss: 0.6936
# Epoch 5/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 416ms/step - binary_accuracy: 0.5079 - loss: 0.6932 - val_binary_accuracy: 0.5375 - val_loss: 0.6930
# Epoch 6/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 414ms/step - binary_accuracy: 0.5121 - loss: 0.6931 - val_binary_accuracy: 0.5250 - val_loss: 0.6929
# Epoch 7/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 403ms/step - binary_accuracy: 0.4825 - loss: 0.6934 - val_binary_accuracy: 0.4625 - val_loss: 0.6933
# Epoch 8/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 400ms/step - binary_accuracy: 0.4868 - loss: 0.6932 - val_binary_accuracy: 0.5625 - val_loss: 0.6925
# Epoch 9/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 396ms/step - binary_accuracy: 0.5503 - loss: 0.6926 - val_binary_accuracy: 0.5375 - val_loss: 0.6923
# Epoch 10/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 399ms/step - binary_accuracy: 0.5166 - loss: 0.6929 - val_binary_accuracy: 0.5125 - val_loss: 0.6928
# Found 25000 files belonging to 2 classes.
# Using 20000 files for training.
# Found 25000 files belonging to 2 classes.
# Using 5000 files for validation.
# Epoch 1/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 927ms/step - binary_accuracy: 0.5194 - loss: 7.1875 - val_binary_accuracy: 0.5156 - val_loss: 0.7206
# Epoch 2/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 891ms/step - binary_accuracy: 0.4856 - loss: 0.7181 - val_binary_accuracy: 0.4812 - val_loss: 0.6954
# Epoch 3/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 853ms/step - binary_accuracy: 0.5000 - loss: 0.6940 - val_binary_accuracy: 0.5281 - val_loss: 0.6934
# Epoch 4/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 874ms/step - binary_accuracy: 0.5139 - loss: 0.6966 - val_binary_accuracy: 0.5031 - val_loss: 0.6973
# Epoch 5/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 814ms/step - binary_accuracy: 0.4782 - loss: 0.7029 - val_binary_accuracy: 0.4750 - val_loss: 0.6938
# Epoch 6/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 795ms/step - binary_accuracy: 0.4659 - loss: 0.6937 - val_binary_accuracy: 0.4781 - val_loss: 0.6935
# Epoch 7/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 821ms/step - binary_accuracy: 0.5255 - loss: 0.6929 - val_binary_accuracy: 0.5188 - val_loss: 0.6931
# Epoch 8/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 808ms/step - binary_accuracy: 0.5405 - loss: 0.6932 - val_binary_accuracy: 0.5312 - val_loss: 0.6930
# Epoch 9/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 802ms/step - binary_accuracy: 0.5360 - loss: 0.6931 - val_binary_accuracy: 0.5188 - val_loss: 0.6930
# Epoch 10/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 831ms/step - binary_accuracy: 0.5021 - loss: 0.6931 - val_binary_accuracy: 0.5000 - val_loss: 0.6931
# Found 25000 files belonging to 2 classes.
# Using 20000 files for training.
# Found 25000 files belonging to 2 classes.
# Using 5000 files for validation.
# Epoch 1/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 270ms/step - binary_accuracy: 0.4035 - loss: 0.8347 - val_binary_accuracy: 0.4500 - val_loss: 0.7030
# Epoch 2/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 220ms/step - binary_accuracy: 0.4630 - loss: 0.7006 - val_binary_accuracy: 0.6375 - val_loss: 0.6919
# Epoch 3/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 207ms/step - binary_accuracy: 0.5818 - loss: 0.6902 - val_binary_accuracy: 0.5125 - val_loss: 0.6924
# Epoch 4/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 220ms/step - binary_accuracy: 0.4866 - loss: 0.7035 - val_binary_accuracy: 0.4750 - val_loss: 0.7002
# Epoch 5/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 207ms/step - binary_accuracy: 0.3938 - loss: 0.7080 - val_binary_accuracy: 0.4500 - val_loss: 0.6939
# Epoch 6/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 208ms/step - binary_accuracy: 0.4877 - loss: 0.6919 - val_binary_accuracy: 0.5375 - val_loss: 0.6941
# Epoch 7/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 223ms/step - binary_accuracy: 0.5509 - loss: 0.6901 - val_binary_accuracy: 0.4875 - val_loss: 0.6922
# Epoch 8/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 211ms/step - binary_accuracy: 0.5715 - loss: 0.6931 - val_binary_accuracy: 0.4375 - val_loss: 0.6919
# Epoch 9/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 218ms/step - binary_accuracy: 0.6590 - loss: 0.6875 - val_binary_accuracy: 0.4625 - val_loss: 0.6997
# Epoch 10/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 223ms/step - binary_accuracy: 0.5179 - loss: 0.7033 - val_binary_accuracy: 0.4625 - val_loss: 0.6899
# Found 25000 files belonging to 2 classes.
# Using 20000 files for training.
# Found 25000 files belonging to 2 classes.
# Using 5000 files for validation.
# Epoch 1/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 440ms/step - binary_accuracy: 0.4769 - loss: 0.7660 - val_binary_accuracy: 0.4812 - val_loss: 0.7104
# Epoch 2/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 473ms/step - binary_accuracy: 0.4966 - loss: 0.7046 - val_binary_accuracy: 0.6125 - val_loss: 0.6898
# Epoch 3/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 404ms/step - binary_accuracy: 0.5446 - loss: 0.6912 - val_binary_accuracy: 0.4750 - val_loss: 0.6946
# Epoch 4/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 420ms/step - binary_accuracy: 0.5156 - loss: 0.6909 - val_binary_accuracy: 0.5312 - val_loss: 0.6879
# Epoch 5/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 416ms/step - binary_accuracy: 0.5188 - loss: 0.6975 - val_binary_accuracy: 0.5688 - val_loss: 0.6889
# Epoch 6/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 403ms/step - binary_accuracy: 0.5121 - loss: 0.6906 - val_binary_accuracy: 0.5312 - val_loss: 0.6857
# Epoch 7/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 418ms/step - binary_accuracy: 0.4887 - loss: 0.6922 - val_binary_accuracy: 0.6125 - val_loss: 0.6868
# Epoch 8/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 412ms/step - binary_accuracy: 0.5669 - loss: 0.6864 - val_binary_accuracy: 0.6313 - val_loss: 0.6795
# Epoch 9/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 400ms/step - binary_accuracy: 0.5513 - loss: 0.6814 - val_binary_accuracy: 0.6438 - val_loss: 0.6717
# Epoch 10/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 440ms/step - binary_accuracy: 0.5638 - loss: 0.6870 - val_binary_accuracy: 0.6187 - val_loss: 0.6587
# Found 25000 files belonging to 2 classes.
# Using 20000 files for training.
# Found 25000 files belonging to 2 classes.
# Using 5000 files for validation.
# Epoch 1/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 884ms/step - binary_accuracy: 0.5132 - loss: 0.8342 - val_binary_accuracy: 0.4844 - val_loss: 0.6968
# Epoch 2/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 832ms/step - binary_accuracy: 0.5212 - loss: 0.6927 - val_binary_accuracy: 0.4969 - val_loss: 0.6942
# Epoch 3/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 839ms/step - binary_accuracy: 0.5095 - loss: 0.6970 - val_binary_accuracy: 0.5781 - val_loss: 0.6898
# Epoch 4/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 820ms/step - binary_accuracy: 0.5736 - loss: 0.6893 - val_binary_accuracy: 0.4969 - val_loss: 0.6829
# Epoch 5/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 833ms/step - binary_accuracy: 0.5248 - loss: 0.6828 - val_binary_accuracy: 0.6313 - val_loss: 0.6729
# Epoch 6/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 833ms/step - binary_accuracy: 0.5925 - loss: 0.6752 - val_binary_accuracy: 0.6281 - val_loss: 0.6613
# Epoch 7/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 858ms/step - binary_accuracy: 0.5883 - loss: 0.6634 - val_binary_accuracy: 0.6250 - val_loss: 0.6673
# Epoch 8/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 860ms/step - binary_accuracy: 0.6144 - loss: 0.6481 - val_binary_accuracy: 0.6438 - val_loss: 0.6496
# Epoch 9/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 836ms/step - binary_accuracy: 0.6374 - loss: 0.6618 - val_binary_accuracy: 0.6812 - val_loss: 0.6570
# Epoch 10/10
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 873ms/step - binary_accuracy: 0.6797 - loss: 0.6389 - val_binary_accuracy: 0.6156 - val_loss: 0.6572

# %% [markdown]
# ## 4. Evaluate the model

# %%
for lr, bs, result in results:
    print(f'Learning Rate: {lr}, Batch Size: {bs}')
    print(f'Train Accuracy: {result.history["binary_accuracy"][-1]}')
    print(f'Validation Accuracy: {result.history["val_binary_accuracy"][-1]}')
# Out:
# Learning Rate: 0.1, Batch Size: 16
# Train Accuracy: 0.5249999761581421
# Validation Accuracy: 0.4625000059604645
# Learning Rate: 0.1, Batch Size: 32
# Train Accuracy: 0.4937500059604645
# Validation Accuracy: 0.48750001192092896
# Learning Rate: 0.1, Batch Size: 64
# Train Accuracy: 0.4937500059604645
# Validation Accuracy: 0.5
# Learning Rate: 0.01, Batch Size: 16
# Train Accuracy: 0.5249999761581421
# Validation Accuracy: 0.4625000059604645
# Learning Rate: 0.01, Batch Size: 32
# Train Accuracy: 0.4937500059604645
# Validation Accuracy: 0.512499988079071
# Learning Rate: 0.01, Batch Size: 64
# Train Accuracy: 0.5062500238418579
# Validation Accuracy: 0.5
# Learning Rate: 0.001, Batch Size: 16
# Train Accuracy: 0.5249999761581421
# Validation Accuracy: 0.4625000059604645
# Learning Rate: 0.001, Batch Size: 32
# Train Accuracy: 0.53125
# Validation Accuracy: 0.6187499761581421
# Learning Rate: 0.001, Batch Size: 64
# Train Accuracy: 0.668749988079071
# Validation Accuracy: 0.6156250238418579
